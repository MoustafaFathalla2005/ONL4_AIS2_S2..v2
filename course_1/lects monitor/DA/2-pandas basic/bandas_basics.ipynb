# %%
import pandas as pd
import numpy as np

# %%
s=pd.Series([1,2,3,4])
# s
# type(s)
s1=pd.Series([1,2,3,4],index=['A','B','C','D'])
s1
# Out:
# A    1
# B    2
# C    3
# D    4
# dtype: int64

# %%
data=[[1,444,'abc'],
      [2,555,'def'],
      [3,666,'ghi'],
      [4,444,'xyz']
      ]
data_2={'ID':[1,2,3,4],
        'std_id_dict':[444,555,666,444]
        ,'dept':['abc','def','ghi','xyz']}

# df=pd.DataFrame(data,columns=['ID','std_id','Dept'])
df=pd.DataFrame(data_2)
# df
display(df)
# Out:
#    ID  std_id_dict dept
# 0   1          444  abc
# 1   2          555  def
# 2   3          666  ghi
# 3   4          444  xyz

# %%
df.columns
# Out:
# Index(['ID', 'std_id_dict', 'dept'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
index=['row1','row2','row3','row4']
df.index=index
display(df)
# o,s,f,i,bool............data type
# Out:
#       ID  std_id_dict dept
# row1   1          444  abc
# row2   2          555  def
# row3   3          666  ghi
# row4   4          444  xyz

# %%
display(df.dtypes)
df['dept'].dtype
# Out:
# ID              int64
# std_id_dict     int64
# dept           object
# dtype: object
# dtype('O')

# %%
# property recap
class person:
    def __init__(self,name):
        self.name=name
        
    @property
    def getInfo(self):
        return f"my name is {self.name}"
    
p1=person('George')
p1.getInfo
# Out:
# 'my name is George'

# %%
df['dept']=df['dept'].astype('category')
df['dept'].dtype
# Out:
# CategoricalDtype(categories=['abc', 'def', 'ghi', 'xyz'], ordered=False, categories_dtype=object)

# %%
df.dtypes
# Out:
# ID                int64
# std_id_dict       int64
# dept           category
# dtype: object

# %%
df.head(2)#5 default
# Out:
#       ID  std_id_dict dept
# row1   1          444  abc
# row2   2          555  def

# %%
df.tail(3)#5
# Out:
#       ID  std_id_dict dept
# row2   2          555  def
# row3   3          666  ghi
# row4   4          444  xyz

# %%
df.describe()
# Out:
#              ID  std_id_dict
# count  4.000000     4.000000
# mean   2.500000   527.250000
# std    1.290994   106.274409
# min    1.000000   444.000000
# 25%    1.750000   444.000000
# 50%    2.500000   499.500000
# 75%    3.250000   582.750000
# max    4.000000   666.000000

# %%
df.describe(include='category')
# Out:
#        dept
# count     4
# unique    4
# top     abc
# freq      1

# %%
x=df['std_id_dict'].unique().sum()
x
# Out:
# np.int64(1665)

# %%
df['std_id_dict'].max()
# Out:
# 666

# %%
df.dept.idxmax()
df.dept.idxmin()
# Out:
# 'row1'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, row1 to row4
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           4 non-null      int64
#  1   std_id_dict  4 non-null      int64
#  2   dept         4 non-null      category
# dtypes: category(1), int64(2)
# memory usage: 476.0+ bytes

# %%
df['dept'].value_counts()
# Out:
# dept
# abc    1
# def    1
# ghi    1
# xyz    1
# Name: count, dtype: int64

# %%
def duplicate(x):
    return x*2

df['std_id_dict'].apply(lambda x:x*2)
# Out:
# row1     888
# row2    1110
# row3    1332
# row4     888
# Name: std_id_dict, dtype: int64

# %%
df['ID'].iloc[2]
df['dept'].iloc[2]
df.iloc[1,1]#see
# Out:
# np.int64(555)

# %%
df.dept.iloc[0:2]
df.iloc[:,0:2]
df.iloc[:,-1:]
# Out:
#      dept
# row1  abc
# row2  def
# row3  ghi
# row4  xyz

# %%
df['new_col']=df.std_id_dict+df.ID
df
# Out:
#       ID  std_id_dict dept  new_col
# row1   1          444  abc      445
# row2   2          555  def      557
# row3   3          666  ghi      669
# row4   4          444  xyz      448

# %%
df.drop('new_col',axis=1)
# Out:
#       ID  std_id_dict dept
# row1   1          444  abc
# row2   2          555  def
# row3   3          666  ghi
# row4   4          444  xyz

# %%
df.drop(['row2','row3'],axis=0)
# Out:
#       ID  std_id_dict dept  new_col
# row1   1          444  abc      445
# row4   4          444  xyz      448

# %%
null=df.isnull()
null
df.isnull().sum()
# Out:
# ID             0
# std_id_dict    0
# dept           0
# new_col        0
# dtype: int64

# %%
# show from 9:45 40??
def isNull(df):
    return

# %%
pd.DataFrame(null).T
