# %%
import pandas as pd

# %%
df=pd.read_csv('train.csv')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df=pd.read_csv('train.csv')
#       2 df
#
# File d:\programs\apps for programming\New folder\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop(['PassengerId','Name','Ticket'],axis=1,inplace=True)
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         0       3    male  22.0      1      0   7.2500   NaN        S
# 1         1       1  female  38.0      1      0  71.2833   C85        C
# 2         1       3  female  26.0      0      0   7.9250   NaN        S
# 3         1       1  female  35.0      1      0  53.1000  C123        S
# 4         0       3    male  35.0      0      0   8.0500   NaN        S

# %%
dtypes=df.dtypes
n_unique=df.nunique()
pd.DataFrame({"Dtype":dtypes,"num_unique":n_unique}).T
# Out:
#            Survived Pclass     Sex      Age  SibSp  Parch     Fare   Cabin  \
# Dtype         int64  int64  object  float64  int64  int64  float64  object
# num_unique        2      3       2       88      7      7      248     147
#
#            Embarked
# Dtype        object
# num_unique        3

# %%
from preprocessing.chk_t import chk_type #ظبطها 
def chk_type(df):
    dtypes=df.dtypes
    n_unique=df.nunique()
    return pd.DataFrame({"Dtype":dtypes,"num_unique":n_unique}).T
chk_type(df)
# Out:
#            Survived Pclass     Sex      Age  SibSp  Parch     Fare   Cabin  \
# Dtype         int64  int64  object  float64  int64  int64  float64  object
# num_unique        2      3       2       88      7      7      248     147
#
#            Embarked
# Dtype        object
# num_unique        3

# %%
def handel_types(cols):
    df[cols]=df[cols].astype('category')
#in files....add()

# %%
cols=['Survived','Pclass','Sex','','']
df[cols]=df[cols].astype('category')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[77], line 2
#       1 cols=['Survived','Pclass','Sex','','']
# ----> 2 df[cols]=df[cols].astype('category')
#
# File d:\programs\apps for programming\New folder\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File d:\programs\apps for programming\New folder\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
# ...

# %%
null=df.isnull().sum()
ratio=null/df.shape[0]
ratio
# Out:
# Survived    0.000000
# Pclass      0.000000
# Sex         0.000000
# Age         0.198653
# SibSp       0.000000
# Parch       0.000000
# Fare        0.000000
# Cabin       0.771044
# Embarked    0.002245
# dtype: float64

# %%
import pandas as pd
def chk_null(df):
    null=df.isnull().sum()
    ratio=null/df.shape[0]
    return pd.DataFrame({"null":null,"ratio":ratio}).T
chk_null(df)
# Out:
#        Survived  Pclass  Sex         Age  SibSp  Parch  Fare       Cabin  \
# null        0.0     0.0  0.0  177.000000    0.0    0.0   0.0  687.000000
# ratio       0.0     0.0  0.0    0.198653    0.0    0.0   0.0    0.771044
#
#        Embarked
# null   2.000000
# ratio  0.002245

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %%
num_col=['Age','Fare']

# %%
num_col=df.select_dtypes('number').columns
plt.figure(figsize=(8,1))
for i ,col in enumerate(,):
