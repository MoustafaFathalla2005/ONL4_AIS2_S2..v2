# %%
list_one=[1,2,3,4,"mou",True,[5,6,7,["m","o"]]]

# %%
print(list_one[6])
print(list_one[6][3][1])
# Out:
# [5, 6, 7, ['m', 'o']]
# o

# %%
list_one.append('ml')
print(list_one)
# Out:
# [1, 2, 3, 4, 'mou', True, [5, 6, 7, ['m', 'o']], 'ml']

# %%
list_one.insert(0,"ml")
print(list_one)
# Out:
# ['ml', 1, 2, 3, 4, 'mou', True, [5, 6, 7, ['m', 'o']], 'ml']

# %%
list_one.extend("mmm")
print(list_one)
# Out:
# ['ml', 1, 2, 3, 4, 'mou', True, [5, 6, 7, ['m', 'o']], 'ml', 'm', 'm', 'm']

# %%
list1=[1,2,3]
list2=[3,5,4]
list3=list1+list2
print(list3)
list1.extend(list2)
print(list1)
# Out:
# [1, 2, 3, 3, 5, 4]
# [1, 2, 3, 3, 5, 4]

# %%
# remove -> add item
# pop ->add index
# del ->add index-???kell
# searchfor defirence

# %%
list_new=['depi','list','mou']
list_new.remove('depi')
list_new
# Out:
# ['list', 'mou']

# %%
list_new.pop(0)
# Out:
# 'list'

# %%
del list_new[0]

# %%
list_new
# Out:
# []

# %%
list_1=[1,2,3]
list_2=[3,5,4]
list_3=[8,9,4]
matrix=[list_1,list_2,list_3]
matrix
# Out:
# [[1, 2, 3], [3, 5, 4], [8, 9, 4]]

# %%
my_list=['one','two','three']
my_list
# Out:
# ['one', 'two', 'three']

# %%
my_list*2
# Out:
# ['one', 'two', 'three', 'one', 'two', 'three']

# %%
# input
name=input("enter your name")
id=int(input("enter your id"))
print("my name is {},my id is {}".format(name,id))
print(type(name),"\n",type(id))
# Out:
# my name is m,my id is 123
# <class 'str'>
#  <class 'int'>

# %%
input_list=['m','o','u']
input_list.extend('stafa')
item=input("enter item to remove")
input_list.remove(item)
print(f'{input_list}')
# Out:
# ['o', 'u', 's', 't', 'a', 'f', 'a']

# %%
mylist=[1,2,3,3,3,3]
index_val=mylist.index(3)
# first index
print(index_val)
count_val=mylist.count(3)
print(count_val)
# Out:
# 2
# 4

# %%
listsort=[5,6,9,8,5,2,1,55,3,5,0]
listsort.sort()
listsort
# Out:
# [0, 1, 2, 3, 5, 5, 5, 6, 8, 9, 55]

# %%
listsort.reverse()
listsort
# Out:
# [55, 9, 8, 6, 5, 5, 5, 3, 2, 1, 0]

# %%
listsort.clear()
listsort
# Out:
# []

# %%
Tuple_one=(1,2,3)
print(Tuple_one)
name='mou'
tuple(name)
# Out:
# (1, 2, 3)
# ('m', 'o', 'u')

# %%
set={1,2,3}
type(set)
# Out:
# set

# %%
set.discard(1)
set
# Out:
# {2, 3}

# %%
a={1,2,3}
b={2,3,4,5}
print(a.difference(b))
# Out:
# {1}

# %%
dict_1={"key":25}
print(type(dict_1))
print(dict_1)
# Out:
# <class 'dict'>
# {'key': 25}

# %%
# TASK
num1=int(input('inter num1'))
num2=int(input('inter num2'))
print(f'{num1}+{num2}=',num1+num2)
print(f'{num1}-{num2}=',num1-num2)
print(f'{num1}*{num2}=',num1*num2)
print(f'{num1}/{num2}=',num1/num2)
print(f'{num1}**{num2}=',num1**num2)
# Out:
# 4+2= 6
# 4-2= 2
# 4*2= 8
# 4/2= 2.0
# 4**2= 16

# %%
a=20
b = 10
if a>b:
    print(a)
else :
    print(b)
# Out:
# 20

# %%
# diffrence between if and elif 
# who see another conditions???

# %%
if (a>0) and (b>0):#parenthesis?()
    print('positive')
# Out:
# positive

# %%
x = 5
res = "even" if a % 2 == 0 else "odd"
print(res)
# Out:
# even

# %%
a=20
b=15
result=a+b if a>b else a-b
print(result)
# Out:
# 35

# %%
age=11
print("adult") if age>20 else print("teenamger") if age>13 else print("child")
# Out:
# child

# %%
is_sunny=True
temp=25

# if is_sunny:

# %%
grade=int(input("enter grade"))
if 50<= grade<=100:
    if 85<= grade<=100:
        print("A")
    elif 75<= grade<=85:
        print("B")
else:
    print('F')
# Out:
# not

# %%
# for
# see diff s
print('--')
for i in range(5):
    print(i)
print('--')
for i in range(5):
    if i ==2 :
        continue
    print(i)
print('--')
for i in range(5):
    if i ==2 :
        pass
    print(i)
print('--')
for i in range(5):
    if i ==2 :
        break
    print(i)
# Out:
# --
# 0
# 1
# 2
# 3
# 4
# --
# 0
# 1
# 3
# 4
# --
# 0
# 1
# 2
# 3
# 4
# --
# 0
# 1

# %%
if x>30:
    pass
# in class --as in abstract class

# %%
# while
x=6
while x>0:
    print("py")
    x-=1
# Out:
# py
# py
# py
# py
# py
# py
