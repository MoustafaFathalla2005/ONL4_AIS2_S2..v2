# %%
print("best")
# Out:
# best

# %%
print("my name is {1} and my age is {0}".format("depi",50))
print("my name is {} and my age is {}".format("depi",50))
name="moustafa"
age=50
print("my name is {} and my age is {}".format(name,age))
print(f"my name is {name} and my age is {age}")
# Out:
# my name is 50 and my age is depi
# my name is depi and my age is 50
# my name is moustafa and my age is 50
# my name is moustafa and my age is 50

# %%
name=input("enter name")
age=int(input("enter age"))
course_name=input("enter course name")
print(f"my name is {name},and my age is {age}.my course is {course_name}")
print("my name is {2},and my age is {1}.my course is {0}".format(course_name,age,name))
# Out:
# my name is mou,and my age is 20.my course is ml
# my name is mou,and my age is 20.my course is ml

# %%
x=30
print(type(x))
# Out:
# <class 'int'>

# %%
name="moustafa"
upper=name.upper()
upper
# Out:
# 'MOUSTAFA'

# %%
lower=upper.lower()
lower
# Out:
# 'moustafa'

# %%
name.replace("stafa"," mou")
# Out:
# 'mou mou'

# %%
name="moustafa fathalla omar"
x=name.split()
print(x,type(x))
response=' '.join(x)
response1=''.join(x)
print(response, type(response))
response1
# Out:
# ['moustafa', 'fathalla', 'omar'] <class 'list'>
# moustafa fathalla omar <class 'str'>
# 'moustafafathallaomar'

# %%
# each var is bool can initial by ='is(its name))?'

# %%
print("hello \nworld")
print("welcome to depi \"machine learning course\"")
print("hello \t world")#\t->4
# \b-->>??
# Out:
# hello
# world
# welcome to depi "machine learning course"
# hello 	 world

# %%
x=2
X=2
print(id(x))
print(id(X))
print(hex(id(x)))
# id->type(int-)
# int->140728308904904
# hex->0x7ffddcdcb3c8
# Out:
# 140728308904904
# 140728308904904
# 0x7ffddcdcb3c8

# %%
# list
# order->you can access data with seq of known index 
# شوف الخصائص والشرح والمقارنة

# %%
#

# %%
name='moustafa'
list(name)
# لازم ليست تبقي اتريبول
# Out:
# ['m', 'o', 'u', 's', 't', 'a', 'f', 'a']
